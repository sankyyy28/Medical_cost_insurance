# %% [markdown]
# <a href="https://colab.research.google.com/github/sankyyy28/Medical_cost_insurance/blob/main/Medical_cost_insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

import warnings

# %% [markdown]
# Importing the Dataset

# %%
df = pd.read_csv('/content/insurance.csv')

# %% [markdown]
#  EDA Operations

# %%
display(df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
plt.figure(figsize=(12,5))

sns.histplot(df['bmi'],kde=True)
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10,4))
sns.boxplot(x=df['bmi'])
plt.title('Boxplot of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency of BMI')
plt.show()

# %%
# remove outlier

Q1 = df['bmi'].quantile(0.25)
Q3 = df['bmi'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"lower : {lower_bound},upper: {upper_bound}")
# Out:
# lower : 13.7,upper: 47.290000000000006

# %%
df.drop_duplicates(inplace= True)

# %%
# cleaning the outlier of the dataset

df_cleaned = df[(df['bmi'] >= lower_bound) & (df['bmi'] <= upper_bound)]

# %%
plt.figure(figsize=(12,5))

sns.histplot(df_cleaned['bmi'],kde=True)
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(12,5))
sns.boxplot(x=df_cleaned['bmi'])
plt.title('Boxplot of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency of BMI')
plt.show()

# %%
# one hot encoding

df_cleaned = pd.get_dummies(df_cleaned,drop_first = True)
df_cleaned
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
#       region_northwest  region_southeast  region_southwest
# 0                False             False              True
# 1                False              True             False
# ...

# %%
df_cleaned.corr()
# Out:
#                        age       bmi  children   charges  sex_male  \
# age               1.000000  0.114785  0.042103  0.301317 -0.018089
# bmi               0.114785  1.000000  0.017366  0.193270  0.039966
# children          0.042103  0.017366  1.000000  0.069125  0.019973
# charges           0.301317  0.193270  0.069125  1.000000  0.064161
# sex_male         -0.018089  0.039966  0.019973  0.064161  1.000000
# smoker_yes       -0.025075 -0.002868  0.007234  0.785896  0.080269
# region_northwest  0.001624 -0.128760  0.025449 -0.036482 -0.011291
# region_southeast -0.012249  0.255903 -0.019239  0.071191  0.010721
# region_southwest  0.009868  0.000655  0.019641 -0.046341 -0.000771
#
#                   smoker_yes  region_northwest  region_southeast  \
# age                -0.025075          0.001624         -0.012249
# bmi                -0.002868         -0.128760          0.255903
# children            0.007234          0.025449         -0.019239
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_cleaned.corr(),annot = True)
# Out:
# <Axes: >

# %%
df_cleaned.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
x = df_cleaned[['bmi','age','smoker_yes']]
y = df_cleaned['charges']

# %%
# train test split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#train the model

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)     # testing on the test data
y_pred_train = model.predict(x_train)   # TESTING ON TRAIN DATA

# %%
print(f" Testing result : {r2_score(y_test,y_pred)}")
print(f" Training result : {r2_score(y_train,y_pred_train)}")
# Out:
#  Testing result : 0.7488004023499726
#  Training result : 0.7455760106931366

# %%
print(f" Testing result : {mean_squared_error(y_test,y_pred)}")
print(f" Testing result : {mean_squared_error(y_train,y_pred_train)}")
# Out:
#  Testing result : 34916425.2612677
#  Testing result : 36901822.67076611

# %%
import pickle

with open("insurance_model.pkl","wb") as f:
  pickle.dump(model,f)
